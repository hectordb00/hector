# %%
# %ls datasets
# Out:
# A2.xlsx                    CasosCovid.xlsx  movies.csv
# adult.csv                  census.csv       nhanes_2015_2016.csv
# airline_data.csv           coches.csv       pokemon.csv
# antropometria00.csv        cwurData.csv     reg_data.csv
# antropometria-dataset.csv  data.csv         sample_pivot.csv
# Book3.csv                  headbrain.csv    tips.csv
# Canada.xlsx                mic2.xlsx        weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('datasets/A2.xlsx',
                  engine = 'openpyxl',
                  )
df
# Out:
#       Year  Quarter ID Quarter  Month ID    Month  Day   Time ID        Time  \
# 0     2020           1      Q1         3  2020-03   15  20200315  2020-03-15
# 1     2020           1      Q1         3  2020-03   15  20200315  2020-03-15
# 2     2020           1      Q1         3  2020-03   15  20200315  2020-03-15
# 3     2020           1      Q1         3  2020-03   15  20200315  2020-03-15
# 4     2020           1      Q1         3  2020-03   15  20200315  2020-03-15
# ...    ...         ...     ...       ...      ...  ...       ...         ...
# 7315  2022           1      Q1         3  2022-03   16  20220316  2022-03-16
# 7316  2022           1      Q1         3  2022-03   16  20220316  2022-03-16
# 7317  2022           1      Q1         3  2022-03   16  20220316  2022-03-16
# 7318  2022           1      Q1         3  2022-03   16  20220316  2022-03-16
# 7319  2022           1      Q1         3  2022-03   16  20220316  2022-03-16
#
# ...

# %% [markdown]
# This dataset consists on the evolution of covid cases since it first started back in March of 2020 until now, March 2022. It states the daily cases and deaths per Municipality.

# %% [markdown]
# The organization that generated this dataset is datamexico.org

# %% [markdown]
# The downloadable dataset file is found on the following link: https://datamexico.org/es/profile/geo/monterrey

# %% [markdown]
# # Questions that could be answered using this dataset:

# %% [markdown]
# 1. What is the difference of covid cases comparing the years of 2020 and 2021?
#
# 2. Which municipality had the most covid cases on January 17, 2022?
#
# 3. Plot a Bar Graph that shows the covid cases on January 17, 20222 using five different municipalities.
#
# 4. What's the median amount of cases on January 17 2022? Demonstrate using a Boxplot.
#
# 5. What year (2020, 2021 or 2022) ha
